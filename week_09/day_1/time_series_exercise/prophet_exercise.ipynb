# %%
# ignore warnings
import warnings
warnings.filterwarnings('ignore')

# import pandas
import pandas as pd

# import matplotlib
import matplotlib.pyplot as plt

# import prophet
from fbprophet import Prophet

# %%
# load data
wmt = pd.read_csv('https://raw.githubusercontent.com/gumdropsteve/intro_to_prophet/master/data/WMT.csv')

# %% [markdown]
# * Explore the dataset

# %%
print(wmt.shape)
wmt.head()
# Out:
# (11815, 7)
#          Date      Open      High       Low     Close  Adj Close   Volume
# 0  1972-08-25  0.063477  0.064697  0.063477  0.064453   0.023768  2508800
# 1  1972-08-28  0.064453  0.064941  0.064209  0.064209   0.023678   972800
# 2  1972-08-29  0.063965  0.063965  0.063477  0.063477   0.023408  1945600
# 3  1972-08-30  0.063477  0.063477  0.062988  0.063477   0.023408   409600
# 4  1972-08-31  0.062988  0.062988  0.062500  0.062500   0.023047   870400

# %% [markdown]
# * use only `Date` and `Adj Close` columns

# %%
wmt = wmt[['Date', 'Adj Close']]
wmt.head()
# Out:
#          Date  Adj Close
# 0  1972-08-25   0.023768
# 1  1972-08-28   0.023678
# 2  1972-08-29   0.023408
# 3  1972-08-30   0.023408
# 4  1972-08-31   0.023047

# %% [markdown]
# * rename columns to fit Prophet naming convention

# %%
wmt = wmt.rename(columns={'Date':'ds', 'Adj Close':'y'})
wmt.head()
# Out:
#            ds         y
# 0  1972-08-25  0.023768
# 1  1972-08-28  0.023678
# 2  1972-08-29  0.023408
# 3  1972-08-30  0.023408
# 4  1972-08-31  0.023047

# %% [markdown]
# * convert date to datetime

# %%
from datetime import datetime

# %%
wmt['ds'] = [datetime.strptime(date, '%Y-%m-%d') for date in wmt['ds']]

# %% [markdown]
# * plot time-series

# %%
wmt.plot('ds', 'y')

# %% [markdown]
# * instantiate Prophet

# %%
prophet = Prophet()

# %% [markdown]
# * fit model

# %%
prophet.fit(wmt)
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 2 threads.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %% [markdown]
# * forecast 365 values in future

# %%
future = prophet.make_future_dataframe(periods=365)
forecast = prophet.predict(future)

# %% [markdown]
# * plot forecast

# %%
fig1 = prophet.plot(forecast)

# %% [markdown]
# * plot components

# %%
fig2 = prophet.plot_components(forecast)

# %% [markdown]
# - Compare the Prophet prediction vs Arima. Use the last 7 values we have in the timeseries as ground truth.

# %%
import itertools
import statsmodels.api as sm

# %%
p = d = q = range(0, 2)
pdq = list(itertools.product(p, d, q))
seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]
print('Examples of parameter combinations for Seasonal ARIMA...')
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[1]))
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[2]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[3]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[4]))
# Out:
# Examples of parameter combinations for Seasonal ARIMA...
# SARIMAX: (0, 0, 1) x (0, 0, 1, 12)
# SARIMAX: (0, 0, 1) x (0, 1, 0, 12)
# SARIMAX: (0, 1, 0) x (0, 1, 1, 12)
# SARIMAX: (0, 1, 0) x (1, 0, 0, 12)

# %%
for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            mod = sm.tsa.statespace.SARIMAX(y,
                                            order=param,
                                            seasonal_order=param_seasonal,
                                            enforce_stationarity=False,
                                            enforce_invertibility=False)
            results = mod.fit()
            print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results.aic))
        except:
            continue

# %%
mod = sm.tsa.statespace.SARIMAX(wmt.values,
                                order=(1, 1, 1),
                                seasonal_order=(1, 1, 0, 12),
                                enforce_stationarity=False,
                                enforce_invertibility=False)
results = mod.fit()
print(results.summary().tables[1])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-b675b6b33084> in <module>()
#       3                                 seasonal_order=(1, 1, 0, 12),
#       4                                 enforce_stationarity=False,
# ----> 5                                 enforce_invertibility=False)
#       6 results = mod.fit()
#       7 print(results.summary().tables[1])
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/statespace/sarimax.py in __init__(self, endog, exog, order, seasonal_order, trend, measurement_error, time_varying_regression, mle_regression, simple_differencing, enforce_stationarity, enforce_invertibility, hamilton_representation, concentrate_scale, **kwargs)
#     535
#     536         # Initialize the fixed components of the statespace model
# --> 537         self.ssm['design'] = self.initial_design
#     538         self.ssm['state_intercept'] = self.initial_state_intercept
#     539         self.ssm['transition'] = self.initial_transition
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/statespace/representation.py in __setitem__(self, key, value)
#     419                 raise IndexError('"%s" is an invalid state space matrix name'
#     420                                  % key)
# --> 421             setattr(self, key, value)
#     422         # If it's a tuple (with a string as the first element) then we must be
#     423         # setting a slice of a matrix
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/statespace/representation.py in __set__(self, obj, value)
#      53
#      54         if len(shape) == 3:
# ---> 55             value = self._set_matrix(obj, value, shape)
#      56         else:
#      57             value = self._set_vector(obj, value, shape)
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/statespace/representation.py in _set_matrix(self, obj, value, shape)
#      68         # Enforce that the matrix is appropriate size
#      69         validate_matrix_shape(
# ---> 70             self.name, value.shape, shape[0], shape[1], obj.nobs
#      71         )
#      72
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/statespace/tools.py in validate_matrix_shape(name, shape, nrows, ncols, nobs)
#    1419         raise ValueError('Invalid value for %s matrix. Requires a'
#    1420                          ' 2- or 3-dimensional array, got %d dimensions' %
# -> 1421                          (name, ndim))
#    1422     # Enforce the shape of the matrix
#    1423     if not shape[0] == nrows:
#
# ValueError: Invalid value for design matrix. Requires a 2- or 3-dimensional array, got 1 dimensions

# %%
decomposition = sm.tsa.seasonal_decompose(wmt, model='additive')
fig = decomposition.plot()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-c865cc20316b> in <module>()
# ----> 1 decomposition = sm.tsa.seasonal_decompose(wmt, model='additive')
#       2 fig = decomposition.plot()
#       3 plt.show()
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/seasonal.py in seasonal_decompose(x, model, filt, freq, two_sided, extrapolate_trend)
#     106     """
#     107     if freq is None:
# --> 108         _pandas_wrapper, pfreq = _maybe_get_pandas_wrapper_freq(x)
#     109     else:
#     110         _pandas_wrapper = _maybe_get_pandas_wrapper(x)
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/filters/_utils.py in _maybe_get_pandas_wrapper_freq(X, trim)
#      46         index = X.index
#      47         func = _get_pandas_wrapper(X, trim)
# ---> 48         freq = index.inferred_freq
#      49         return func, freq
#      50     else:
#
# AttributeError: 'RangeIndex' object has no attribute 'inferred_freq'
