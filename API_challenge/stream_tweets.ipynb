# %%
import twitter
# ADD OTHER PACKAGES WE WILL NEED
# <HERE>

# %% [markdown]
# **Task:** Load the values of access tokens and keys from environmental variables to python variables

# %%
consumer_key = # CODE HERE
consumer_secret = # CODE HERE
access_token = # CODE HERE
access_token_secret = # CODE HERE

# %%
api = twitter.Api(consumer_key=consumer_key,
                  consumer_secret=consumer_secret,
                  access_token_key=access_token,
                  access_token_secret=access_token_secret)

# %%
# Checking the type of api object
print(type(api))
# Out:
# <class 'twitter.api.Api'>

# %%
## FOLLOWING FUNCTION WILL COLLECT REAL-TIME TWEETS IN OUR COMPUTER

# data returned will be for any tweet mentioning strings in the list FILTER
FILTER = ['#datascience']

# Languages to filter tweets by is a list. This will be joined by Twitter
# to return data mentioning tweets only in the english language.
LANGUAGES = ['en']


def main():
    with open('output.txt', 'a') as f:
        # api.GetStreamFilter will return a generator that yields one status
        # message (i.e., Tweet) at a time as a JSON dictionary.
        for line in api.GetStreamFilter(track=FILTER, languages=LANGUAGES):
            f.write(json.dumps(line))
            f.write('\n')

# %%
# Execute function
main()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-263240bbee7e> in <module>
# ----> 1 main()
#
# <ipython-input-25-c81803b3aa6e> in main()
#      12         # api.GetStreamFilter will return a generator that yields one status
#      13         # message (i.e., Tweet) at a time as a JSON dictionary.
# ---> 14         for line in api.GetStreamFilter(track=FILTER, languages=LANGUAGES):
#      15             f.write(json.dumps(line))
#      16             f.write('\n')
#
# ~/anaconda3/lib/python3.7/site-packages/twitter/api.py in GetStreamFilter(self, follow, track, locations, languages, delimited, stall_warnings, filter_level)
#    4591
#    4592         resp = self._RequestStream(url, 'POST', data=data)
# -> 4593         for line in resp.iter_lines():
#    4594             if line:
#    4595                 data = self._ParseAndCheckTwitter(line.decode('utf-8'))
#
# ~/anaconda3/lib/python3.7/site-packages/requests/models.py in iter_lines(self, chunk_size, decode_unicode, delimiter)
#     792         pending = None
#     793
# --> 794         for chunk in self.iter_content(chunk_size=chunk_size, decode_unicode=decode_unicode):
#     795
#     796             if pending is not None:
#
# ~/anaconda3/lib/python3.7/site-packages/requests/models.py in generate()
#     748             if hasattr(self.raw, 'stream'):
#     749                 try:
# --> 750                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     751                         yield chunk
#     752                 except ProtocolError as e:
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/response.py in stream(self, amt, decode_content)
#     558         """
#     559         if self.chunked and self.supports_chunked_reads():
# --> 560             for line in self.read_chunked(amt, decode_content=decode_content):
#     561                 yield line
#     562         else:
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/response.py in read_chunked(self, amt, decode_content)
#     750
#     751             while True:
# --> 752                 self._update_chunk_length()
#     753                 if self.chunk_left == 0:
#     754                     break
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/response.py in _update_chunk_length(self)
#     680         if self.chunk_left is not None:
#     681             return
# --> 682         line = self._fp.fp.readline()
#     683         line = line.split(b";", 1)[0]
#     684         try:
#
# ~/anaconda3/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     311     def recv_into(self, *args, **kwargs):
#     312         try:
# --> 313             return self.connection.recv_into(*args, **kwargs)
#     314         except OpenSSL.SSL.SysCallError as e:
#     315             if self.suppress_ragged_eofs and e.args == (-1, "Unexpected EOF"):
#
# ~/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1837             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1838         else:
# -> 1839             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1840         self._raise_ssl_error(self._ssl, result)
#    1841
#
# KeyboardInterrupt:

# %% [markdown]
# **Task:** Edit function `main` so it can store tweets anywhere (location specified as parameter). The FILTER and LANGUAGES should be parameters as well. Test it with different values and languages.

# %% [markdown]
# **Task:** Create File `stream_tweets.py` that can be executed from the Terminal

# %% [markdown]
# **Task:** Start storing tweets with either happy smiley (`:)`) or sad smiley (`:(`). We will use this dataset during the NLP section.
