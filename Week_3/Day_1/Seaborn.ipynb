# %%
# import seaborn
import seaborn as sns

# import matplotlib
import matplotlib.pyplot as plt

# load the built-in tips dataset
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ## Regression Line with a Confidence Interval

# %%
# a regression line with a confidence inetrval plot
sns.lmplot(x='total_bill', y='tip', data = tips)
plt.show()

# %%
sns.lmplot(x='total_bill',y='tip', data = tips, hue = 'sex')
plt.show()

# %%
sns.lmplot(x='total_bill',y='tip', data = tips, col = 'sex')
plt.show()

# %% [markdown]
# ## Residual Plot

# %%
sns.residplot(x='total_bill',y='tip', data = tips)
plt.show()

# %% [markdown]
# ## Strip Plot

# %%
sns.stripplot(x='day',y ='tip',data = tips, size =5, jitter = True)

# overwrite the original y-label from 'tip' to 'tip ($)'
plt.ylabel('tip ($)')
plt.show()

# %% [markdown]
# ## Swarm Plot

# %%
sns.swarmplot(x='day',y='tip',data = tips, hue = 'sex')

# overwrite the original y-label from 'tip' to 'tip ($)'
plt.ylabel('tip ($)')
plt.show()
# Out:
# D:\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 6.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# D:\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 5.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## Boxplot + Violine Plot

# %%
# create a grid with 1 row 2 columns
plt.subplot(1,2,1)

# the first plot
sns.boxplot(x='day',y='tip', data = tips)
plt.ylabel('tip ($)')

plt.subplot(1,2,2)

# the second plot
sns.violinplot(x='day',y='tip', data = tips)
plt.ylabel('tip ($)')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Joint Plot

# %%
sns.jointplot(x='total_bill', y='tip', data = tips)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-1d49d1eea5d4> in <module>
# ----> 1 sns.jointplot(x='total_bill', y='tip', data = tips)
#       2 plt.show()
#
# D:\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# D:\anaconda3\lib\site-packages\seaborn\axisgrid.py in jointplot(x, y, data, kind, color, height, ratio, space, dropna, xlim, ylim, marginal_ticks, joint_kws, marginal_kws, hue, palette, hue_order, hue_norm, **kwargs)
#    2119
#    2120     # Initialize the JointGrid object
# -> 2121     grid = JointGrid(
#    2122         data=data, x=x, y=y, hue=hue,
#    2123         palette=palette, hue_order=hue_order, hue_norm=hue_norm,
#
# D:\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# D:\anaconda3\lib\site-packages\seaborn\axisgrid.py in __init__(self, x, y, data, height, ratio, space, dropna, xlim, ylim, size, marginal_ticks, hue, palette, hue_order, hue_norm)
#    1628
#    1629         # Process the input variables
# -> 1630         p = VectorPlotter(data=data, variables=dict(x=x, y=y, hue=hue))
#    1631         plot_data = p.plot_data.loc[:, p.plot_data.notna().any()]
#    1632
#
# D:\anaconda3\lib\site-packages\seaborn\_core.py in __init__(self, data, variables)
#     602     def __init__(self, data=None, variables={}):
#     603
# --> 604         self.assign_variables(data, variables)
#     605
#     606         for var, cls in self._semantic_mappings.items():
#
# D:\anaconda3\lib\site-packages\seaborn\_core.py in assign_variables(self, data, variables)
#     665         else:
#     666             self.input_format = "long"
# --> 667             plot_data, variables = self._assign_variables_longform(
#     668                 data, **variables,
#     669             )
#
# D:\anaconda3\lib\site-packages\seaborn\_core.py in _assign_variables_longform(self, data, **kwargs)
#     924         # Construct a tidy plot DataFrame. This will convert a number of
#     925         # types automatically, aligning on index in case of pandas objects
# --> 926         plot_data = pd.DataFrame(plot_data)
#     927
#     928         # Reduce the variables dictionary to fields with valid data
#
# D:\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     433             )
#     434         elif isinstance(data, dict):
# --> 435             mgr = init_dict(data, index, columns, dtype=dtype)
#     436         elif isinstance(data, ma.MaskedArray):
#     437             import numpy.ma.mrecords as mrecords
#
# D:\anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     252             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     253         ]
# --> 254     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     255
#     256
#
# D:\anaconda3\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#      67
#      68     # don't force copy because getting jammed in an ndarray anyway
# ---> 69     arrays = _homogenize(arrays, index, dtype)
#      70
#      71     # from BlockManager perspective
#
# D:\anaconda3\lib\site-packages\pandas\core\internals\construction.py in _homogenize(data, index, dtype)
#     320                     val = dict(val)
#     321                 val = lib.fast_multiget(val, oindex.values, default=np.nan)
# --> 322             val = sanitize_array(
#     323                 val, index, dtype=dtype, copy=False, raise_cast_failure=False
#     324             )
#
# D:\anaconda3\lib\site-packages\pandas\core\construction.py in sanitize_array(data, index, dtype, copy, raise_cast_failure)
#     463                 value = maybe_cast_to_datetime(value, dtype)
#     464
# --> 465             subarr = construct_1d_arraylike_from_scalar(value, len(index), dtype)
#     466
#     467         else:
#
# D:\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in construct_1d_arraylike_from_scalar(value, length, dtype)
#    1459                 value = ensure_str(value)
#    1460
# -> 1461         subarr = np.empty(length, dtype=dtype)
#    1462         subarr.fill(value)
#    1463
#
# TypeError: Cannot interpret '<attribute 'dtype' of 'numpy.generic' objects>' as a data type

# %%
sns.jointplot(x='total_bill', y='tip', data = tips, kind = 'kde')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-a9cb969f429f> in <module>
# ----> 1 sns.jointplot(x='total_bill', y='tip', data = tips, kind = 'kde')
#       2 plt.show()
#
# D:\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# D:\anaconda3\lib\site-packages\seaborn\axisgrid.py in jointplot(x, y, data, kind, color, height, ratio, space, dropna, xlim, ylim, marginal_ticks, joint_kws, marginal_kws, hue, palette, hue_order, hue_norm, **kwargs)
#    2119
#    2120     # Initialize the JointGrid object
# -> 2121     grid = JointGrid(
#    2122         data=data, x=x, y=y, hue=hue,
#    2123         palette=palette, hue_order=hue_order, hue_norm=hue_norm,
#
# D:\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# D:\anaconda3\lib\site-packages\seaborn\axisgrid.py in __init__(self, x, y, data, height, ratio, space, dropna, xlim, ylim, size, marginal_ticks, hue, palette, hue_order, hue_norm)
#    1628
#    1629         # Process the input variables
# -> 1630         p = VectorPlotter(data=data, variables=dict(x=x, y=y, hue=hue))
#    1631         plot_data = p.plot_data.loc[:, p.plot_data.notna().any()]
#    1632
#
# D:\anaconda3\lib\site-packages\seaborn\_core.py in __init__(self, data, variables)
#     602     def __init__(self, data=None, variables={}):
#     603
# --> 604         self.assign_variables(data, variables)
#     605
#     606         for var, cls in self._semantic_mappings.items():
#
# D:\anaconda3\lib\site-packages\seaborn\_core.py in assign_variables(self, data, variables)
#     665         else:
#     666             self.input_format = "long"
# --> 667             plot_data, variables = self._assign_variables_longform(
#     668                 data, **variables,
#     669             )
#
# D:\anaconda3\lib\site-packages\seaborn\_core.py in _assign_variables_longform(self, data, **kwargs)
#     924         # Construct a tidy plot DataFrame. This will convert a number of
#     925         # types automatically, aligning on index in case of pandas objects
# --> 926         plot_data = pd.DataFrame(plot_data)
#     927
#     928         # Reduce the variables dictionary to fields with valid data
#
# D:\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     433             )
#     434         elif isinstance(data, dict):
# --> 435             mgr = init_dict(data, index, columns, dtype=dtype)
#     436         elif isinstance(data, ma.MaskedArray):
#     437             import numpy.ma.mrecords as mrecords
#
# D:\anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     252             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     253         ]
# --> 254     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     255
#     256
#
# D:\anaconda3\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#      67
#      68     # don't force copy because getting jammed in an ndarray anyway
# ---> 69     arrays = _homogenize(arrays, index, dtype)
#      70
#      71     # from BlockManager perspective
#
# D:\anaconda3\lib\site-packages\pandas\core\internals\construction.py in _homogenize(data, index, dtype)
#     320                     val = dict(val)
#     321                 val = lib.fast_multiget(val, oindex.values, default=np.nan)
# --> 322             val = sanitize_array(
#     323                 val, index, dtype=dtype, copy=False, raise_cast_failure=False
#     324             )
#
# D:\anaconda3\lib\site-packages\pandas\core\construction.py in sanitize_array(data, index, dtype, copy, raise_cast_failure)
#     463                 value = maybe_cast_to_datetime(value, dtype)
#     464
# --> 465             subarr = construct_1d_arraylike_from_scalar(value, len(index), dtype)
#     466
#     467         else:
#
# D:\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in construct_1d_arraylike_from_scalar(value, length, dtype)
#    1459                 value = ensure_str(value)
#    1460
# -> 1461         subarr = np.empty(length, dtype=dtype)
#    1462         subarr.fill(value)
#    1463
#
# TypeError: Cannot interpret '<attribute 'dtype' of 'numpy.generic' objects>' as a data type

# %% [markdown]
# ## Pair Plot

# %%
sns.pairplot(tips)
plt.show()

# %%
sns.pairplot(tips, hue = 'sex')
plt.show()

# %% [markdown]
# ## Heatmap

# %%
# compute correlations between features
df_corr = tips.corr()

# plot the correlations
sns.heatmap(df_corr)
plt.title('Correlation plot')
plt.show()
